# %%
def welcome_message():    #no param no return type
    print("Hello User")

welcome_message()

print(type(welcome_message()))
# Out:
# Hello User
# Hello User
# <class 'NoneType'>

# %%
def adder(a,b):
    sum=a+b
    return sum
print(type(adder(10,20)))
# Out:
# <class 'int'>

# %%
def adder(a,b):
    sum=a+b
    return sum
print(type(adder(10.5,20)))
# Out:
# <class 'float'>

# %%
def welcome_message(user):    #no param no return type
    return f"Hello {user}"

print(type(welcome_message("Phitron")))
# Out:
# <class 'str'>

# %%
def adder(a,b):
    
    return a,b
print(type(adder(10,20)))
# Out:
# <class 'tuple'>

# %%
def adder(a,b):
    
    return a,b
print(type(adder(10,20)))

#unzip
x,y = adder (10.5,20)
print(x,y)
# Out:
# <class 'tuple'>
# 10.5 20
