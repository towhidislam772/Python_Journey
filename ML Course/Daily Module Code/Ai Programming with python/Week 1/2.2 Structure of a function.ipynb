# %%
def welcome_message():    #no param no return type
    print("Hello User")

welcome_message()
# Out:
# Hello User

# %%
def welcome_message(user):    #no param no return type
    print(f"Hello {user}")

welcome_message("Phitron")
# Out:
# Hello Phitron

# %%
def welcome_message(user ="None"):    #no param no return type #dedault input
    print(f"Hello {user}")

welcome_message()
# Out:
# Hello None
