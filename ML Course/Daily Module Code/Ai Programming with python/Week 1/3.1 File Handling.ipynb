# %%
file = open("./sample_data/sample.txt","r")

content = file.read()

print(type(content))

file.close()
print(file.closed)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file = open("./sample_data/sample.txt","r")
#       2
#       3 content = file.read()
#       4
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/sample.txt'
