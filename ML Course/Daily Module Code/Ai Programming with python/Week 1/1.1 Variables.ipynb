# %%
a = 10

print(a)

print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 10.5

print(type(b))
# Out:
# <class 'float'>

# %%
a = b

print(a)
print(type(a))
# Out:
# 10.5
# <class 'float'>

# %%
name = "phitron"

print(type(name))
# Out:
# <class 'str'>

# %%
data = input()

print(data)
print(type(data))
# Out:
# hi
# <class 'str'>

# %%
a = input()
a = int(a)
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>
