# %%
a = 10

print(a)

print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 10.5

print(type(b))
# Out:
# <class 'float'>

# %%
a = b

print(a)
print(type(a))
# Out:
# 10.5
# <class 'float'>

# %%
name = "phitron"

print(type(name))
# Out:
# <class 'str'>

# %%
data = input()

print(data)
print(type(data))
# Out:
# 10
# <class 'str'>

# %%
a = input()
a = int(a)
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
row_number = input()

numbers = row_number.split()

a = int(numbers[0])
print(a)
print(type(a))


b = int(numbers[1])

print(b)
print(type(b))

print(a+b)
# Out:
# 10
# <class 'int'>
# 20
# <class 'int'>
# 30
