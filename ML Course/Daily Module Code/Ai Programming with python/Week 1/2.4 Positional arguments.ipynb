# %%
def adder(a,b):
    print(f"{a},{b}")

adder(10,20)
#position matters 
#positional argument
# Out:
# 10,20

# %%
def adder(*args):
    print(args) #touple

adder(10,20)
# Out:
# (10, 20)

# %%
def adder(*args):
    for i in args:
        print(i)

adder(10,20)
# Out:
# 10
# 20
