# %% [markdown]
# Problem 1
#  Write a function introduce(name, age) that prints:
#
#  My name is <name> and I am <age> years old.
#
# Call it using positional arguments.
#
# Sample Input:
# Rhim 28
# Sample Output:
# My name is Rahim and I am 28 years old.

# %%
def introduce(name,age):
    print(f"My name is {name} and I am {age} years old.")

name = input()
age = int(input())

introduce(name,age)
# Out:
# My name is Towhid and I am 24 years old.

# %% [markdown]
# Problem 2
# Write a Python generator function called batch_generator. It should take a list of numbers (representing data samples) and a batch_size. The generator should yield one batch at a time as a list.
#
# Example Input:
# data = [1, 2, 3, 4, 5, 6, 7, 8]
# batch_size = 3
#
# Expected Output (when iterated):
# [1, 2, 3]
# [4, 5, 6]
# [7, 8]

# %%
data = [1, 2, 3, 4, 5, 6, 7, 8]
batch_size = 3

def data_loader(batch_size,list):
    for i in range(0,len(data),batch_size):
        yield data[i:i+batch_size]


for datas in data_loader(batch_size,data):
    print(datas)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8]

# %% [markdown]
# Problem 3
# Given a list [1,2,3,4], use map() and lambda to create a new list with squares of each number.
#
# Sample Input:
#  No input
#
# Sample Output:
# [1, 4, 9, 16]

# %%
lst=[1,2,3,4]

lst_updated = list(map(lambda x: x*x,lst))

lst_updated
# Out:
# [1, 4, 9, 16]

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3, 4]})

df['A'] = df['A'].apply(lambda x: x ** 2)

print(df)
# Out:
#     A
# 0   1
# 1   4
# 2   9
# 3  16

# %% [markdown]
# Problem 4
#  Write a function power(base, exponent) that returns the result of base raised to exponent. If the exponent is not given, it should calculate the square.
# Sample Input:
# 5
# Sample Output:
# 25
# Sample Input 2:
# 5 3
# Sample Output 2:
# 125

# %%
inp=input()
inpt=inp.split()

def power(base, exponent=2):
    return base ** exponent

if len(inpt)==1:
    print(power(int(inpt[0])))
else:    
    print(power(int(inpt[0]),int(inpt[1])))
# Out:
# 15625

# %% [markdown]
# Problem 5 ( Conceptual Session )
# Given a list [1,2,3,4,5,6], use filter() to select even numbers and map() with lambda to square them.
# Sample Input:
#  No input
# Sample Output:
# [4, 16, 36]

# %%
lst=[1,2,3,4,5,6]

lst_even = list(filter(lambda x: x % 2 == 0, lst))
lst_updated = list(map(lambda x: x*x,lst_even))

lst_updated
# Out:
# [4, 16, 36]
