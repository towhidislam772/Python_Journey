# %%
name = input("what is your name?")
print(name)
# Out:
# Phitron

# %%
age = input("age ?")
print(age, type(age))
# Out:
# 25 <class 'str'>

# %%
age = int(input("age ?"))
print(age, type(age))
# Out:
# 10 <class 'int'>

# %%
height = input("Height ?")
print(height, type(height))
# Out:
# 12.6 <class 'str'>

# %%
height = input("Height ?")
height = float(height)
print(height, type(height))
# Out:
# 12.6 <class 'float'>
