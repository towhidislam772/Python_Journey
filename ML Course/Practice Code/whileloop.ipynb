# %%
#while

count=1
while count <10 :
    print(count)
    count=count+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
count=5
while count <10 :
    print(count)
    count=count+1
# Out:
# 5
# 6
# 7
# 8
# 9
