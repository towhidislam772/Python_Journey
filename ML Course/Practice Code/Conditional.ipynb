# %%
raining = True

if raining == True:
    print("Umbrella")
else:
    print("No umbrella")
# Out:
# Umbrella

# %%
raining = True
muddy= False

if raining == True:
    print("Umbrella")
    if muddy == True:
        print("bring shoe")
    else:
        print("No shoes")
else:
    print("No umbrella")
# Out:
# Umbrella
# No shoes

# %%
taka = 1000

if taka >= 500:
    print("ghurte jabo")
elif taka>=400:
    print("bashay order")
elif taka >=300:
    print("Food court")
else:
    print("savings")
# Out:
# ghurte jabo

# %%
taka = 1000
raining = False

if (taka >= 500) and (raining == False):
    print("ghurte jabo")
else:
    print("savings")
# Out:
# ghurte jabo
