# %%
phone_number = 1234
print(phone_number)
# Out:
# 1234

# %%
name = "Phitron"
print(name)
# Out:
# Phitron

# %%
age = 20
height = 5.6
name = "Akash"
is_passed = True

print(type(age),
type(height),
type(name),
type(is_passed))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
