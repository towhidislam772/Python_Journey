# %%
numbers= input()

listed = numbers.split()

#print(listed)

n1=int(listed[0])
n2=int(listed[1])
n3=int(listed[2])

min=n1
max=n1

for i in range(3):
    if min>n2 :
        min=n2
    elif min>n3:
        min=n3
    
for i in range(3):
    if max<n2:
        max=n2
    elif max<n3:
        max=n3

print(min,max)
# Out:
# 1 3

# %%
numbers= input()

listed = numbers.split()

#print(listed) 

n1=int(listed[0])
n2=int(listed[1])
n3=int(listed[2])

min=n1
max=n1


if min>n2 :
    min=n2
if min>n3:
    min=n3
    

if max<n2:
    max=n2
if max<n3:
    max=n3

print(min,max)
# Out:
# -5 20
