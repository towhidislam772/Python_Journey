# %%
x = int(input("Enter First Number"))
y = int(input("Enter Second Number"))

#for last digit mod with 10

last_dig_x = x%10
last_dig_y = y%10

sum = last_dig_x + last_dig_y

print (sum)

# %%
inp=input()

numbers=inp.split()

x=int(numbers[0])
y=int(numbers[1])

last_dig_x = x%10
last_dig_y = y%10

sum = last_dig_x + last_dig_y

print (sum)
# Out:
# 5
