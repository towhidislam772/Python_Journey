# %% [markdown]
# Logical Operator

# %%
x=10; y=5;z=3
result = (x>y) and (x>z)

print(result)
# Out:
# True

# %%
x=10; y=5; z=15
result = (x>y) and (x>z)

print(result)
# Out:
# False

# %%
x=10; y=5; z=15
result = (x>y) or (x>z)

print(result)
# Out:
# True

# %%
x=10; y=20; z=15
result = (x>y) or (x>z)

print(result)
# Out:
# False

# %% [markdown]
# **Precedence And Associativity**

# %%
eq = 10+10/2 - 5*2       #left to right
print(eq)
# Out:
# 5.0

# %%
eq = (10+10)/2 - 5*2       #left to right
print(eq)
# Out:
# 0.0
